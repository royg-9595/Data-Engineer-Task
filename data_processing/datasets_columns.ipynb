# %%
import os
import pandas as pd
import pyarrow.parquet as pq

# %%
def process_file(file_path):
    if file_path.endswith('.csv'):
        df = pd.read_csv(file_path)
    elif file_path.endswith('.xlsx') or file_path.endswith('.xls'):
        df = pd.read_excel(file_path)
    elif file_path.endswith('.parquet'):
        df = pq.read_table(file_path).to_pandas()
    else:
        print(f"Unsupported file format: {file_path}")
        return
    
    print(f"\nFile: {os.path.basename(file_path)}")
    print("Columns:", list(df.columns))
    print("First Record:")
    print(df.iloc[0] if not df.empty else "No records found")

# %%
current_dir = os.path.dirname(os.getcwd())
folder_path = os.path.join(current_dir,'datasets')

# %%
for file_name in os.listdir(folder_path):
    file_path = os.path.join(folder_path, file_name)
    if os.path.isfile(file_path):
        process_file(file_path)
# Out:
# File: conditions.xlsx
# Columns: ['START', 'STOP', 'PATIENT', 'ENCOUNTER', 'CODE', 'DESCRIPTION']
# First Record:
# START                                    2020-04-21
# STOP                                            NaN
# PATIENT        28D7B56C-6056-D0A2-2991-39D6E917216C
# ENCOUNTER      402dfaeb-1888-f562-4651-f75203eb1e28
# CODE                                      200936003
# DESCRIPTION                     Lupus erythematosus
# Name: 0, dtype: object
#
# File: encounters.parquet
# Columns: ['Id', 'START', 'STOP', 'PATIENT', 'ORGANIZATION', 'PROVIDER', 'PAYER', 'ENCOUNTERCLASS', 'CODE', 'DESCRIPTION', 'BASE_ENCOUNTER_COST', 'TOTAL_CLAIM_COST', 'PAYER_COVERAGE', 'REASONCODE', 'REASONDESCRIPTION']
# First Record:
# Id                     6539c675-dcf2-cace-a90d-7f097d1799b3
# START                                  2014-02-10T11:00:08Z
# STOP                                   2014-02-10T11:15:08Z
# PATIENT                54F1059E-6250-3949-6DD0-1DDA9B85D22A
# ORGANIZATION           ef42ec52-a1c1-3fc5-8e52-da46f7f3970c
# PROVIDER               35088bec-f756-35d8-8140-b2b017c0eacc
# PAYER                  8fa6c185-e44e-3e34-8bd8-39be8694f4ce
# ENCOUNTERCLASS                                     wellness
# CODE                                              410620009
# DESCRIPTION                    Well child visit (procedure)
# BASE_ENCOUNTER_COST                                  133.36
# TOTAL_CLAIM_COST                                     405.36
# PAYER_COVERAGE                                          0.0
# REASONCODE                                              NaN
# REASONDESCRIPTION                                      None
# Name: 0, dtype: object
#
# File: medications.csv
# Columns: ['START', 'STOP', 'PATIENT', 'PAYER', 'ENCOUNTER', 'CODE', 'DESCRIPTION', 'BASE_COST', 'PAYER_COVERAGE', 'DISPENSES', 'TOTALCOST', 'REASONCODE', 'REASONDESCRIPTION']
# First Record:
# START                                2020-04-22T02:47:09Z
# STOP                                                  NaN
# PATIENT              28d7b56c-6056-d0a2-2991-39d6e917216c
# PAYER                0133f751-9229-3cfd-815f-b6d4979bdd6a
# ENCOUNTER            402DFAEB-1888-F562-4651-F75203EB1E28
# CODE                                               849574
# DESCRIPTION            Naproxen sodium 220 MG Oral Tablet
# BASE_COST                                          274.28
# PAYER_COVERAGE                                        0.0
# DISPENSES                                              45
# TOTALCOST                                         12342.6
# REASONCODE                                    200936003.0
# REASONDESCRIPTION                     Lupus erythematosus
# Name: 0, dtype: object
#
# File: patients.csv
# Columns: ['PATIENT_ID', 'BIRTHDATE', 'DEATHDATE', 'SSN', 'DRIVERS', 'PASSPORT', 'PREFIX', 'FIRST', 'LAST', 'SUFFIX', 'MAIDEN', 'MARITAL', 'RACE', 'ETHNICITY', 'GENDER', 'BIRTHPLACE', 'ADDRESS', 'CITY', 'STATE', 'COUNTY', 'FIPS', 'ZIP', 'LAT', 'LON', 'HEALTHCARE_EXPENSES', 'HEALTHCARE_COVERAGE', 'INCOME']
# First Record:
# PATIENT_ID             54f1059e-6250-3949-6dd0-1dda9b85d22a
# BIRTHDATE                                        2002-01-21
# DEATHDATE                                               NaN
# SSN                                             999-28-3364
# DRIVERS                                           S99987398
# PASSPORT                                         X44428214X
# PREFIX                                                  Ms.
# FIRST                                          Fredricka415
# LAST                                               Crist667
# SUFFIX                                                  NaN
# MAIDEN                                                  NaN
# MARITAL                                                 NaN
# RACE                                                  white
# ETHNICITY                                       nonhispanic
# GENDER                                                  NaN
# BIRTHPLACE                           San Antonio  Texas  US
# ADDRESS                            931 Bartell Ville Apt 84
# CITY                                             Fort Worth
# STATE                                                 Texas
# COUNTY                                       Tarrant County
# FIPS                                                48439.0
# ZIP                                                   76104
# LAT                                                0.329154
# LON                                              -97.399553
# HEALTHCARE_EXPENSES                                 9990.08
# HEALTHCARE_COVERAGE                                     0.0
# INCOME                                                35460
# Name: 0, dtype: object
#
# File: patient_gender.csv
# Columns: ['Id', 'GENDER']
# First Record:
# Id        54f1059e-6250-3949-6dd0-1dda9b85d22a
# GENDER                                       F
# Name: 0, dtype: object
#
# File: symptoms.csv
# Columns: ['PATIENT', 'GENDER', 'RACE', 'ETHNICITY', 'AGE_BEGIN', 'AGE_END', 'PATHOLOGY', 'NUM_SYMPTOMS', 'SYMPTOMS']
# First Record:
# PATIENT             28d7b56c-6056-d0a2-2991-39d6e917216c
# GENDER                                               NaN
# RACE                                               white
# ETHNICITY                                       hispanic
# AGE_BEGIN                                             26
# AGE_END                                              NaN
# PATHOLOGY                            Lupus erythematosus
# NUM_SYMPTOMS                                           4
# SYMPTOMS        Rash:34;Joint Pain:39;Fatigue:9;Fever:12
# Name: 0, dtype: object
